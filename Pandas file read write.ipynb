# %%
import pandas as pd

# %% [markdown]
# ### https://github.com/training-ml/Files

# %%
IPL_Data= pd.read_csv("https://raw.githubusercontent.com/training-ml/Files/main/matches.csv")

# %%
IPL_Data
# Out:
#       id  season       city      date                        team1  \
# 0      1    2017  Hyderabad  05/04/17          Sunrisers Hyderabad
# 1      2    2017       Pune  06/04/17               Mumbai Indians
# 2      3    2017     Rajkot  07/04/17                Gujarat Lions
# 3      4    2017     Indore  08/04/17       Rising Pune Supergiant
# 4      5    2017  Bangalore  08/04/17  Royal Challengers Bangalore
# ..   ...     ...        ...       ...                          ...
# 631  632    2016     Raipur  22/05/16             Delhi Daredevils
# 632  633    2016  Bangalore  24/05/16                Gujarat Lions
# 633  634    2016      Delhi  25/05/16          Sunrisers Hyderabad
# 634  635    2016      Delhi  27/05/16                Gujarat Lions
# 635  636    2016  Bangalore  29/05/16          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %% [markdown]
# ### if you want to display all the rows of data set then write below code before upload the data set and after import the pandas library.
#
# #### pd.set_option('display.max_rows',None)

# %%
 IPL_Data.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  05/04/17          Sunrisers Hyderabad
# 1   2    2017       Pune  06/04/17               Mumbai Indians
# 2   3    2017     Rajkot  07/04/17                Gujarat Lions
# 3   4    2017     Indore  08/04/17       Rising Pune Supergiant
# 4   5    2017  Bangalore  08/04/17  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
IPL_Data.tail()
# Out:
#       id  season       city      date                team1  \
# 631  632    2016     Raipur  22/05/16     Delhi Daredevils
# 632  633    2016  Bangalore  24/05/16        Gujarat Lions
# 633  634    2016      Delhi  25/05/16  Sunrisers Hyderabad
# 634  635    2016      Delhi  27/05/16        Gujarat Lions
# 635  636    2016  Bangalore  29/05/16  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
 IPL_Data.sample(n=8)
# Out:
#       id  season        city      date                        team1  \
# 365  366    2012  Chandigarh  13/05/12              Deccan Chargers
# 549  550    2015   Bangalore  02/05/15        Kolkata Knight Riders
# 123  124    2009   Cape Town  22/04/09              Deccan Chargers
# 613  614    2016     Kolkata  08/05/16        Kolkata Knight Riders
# 106  107    2008     Chennai  21/05/08  Royal Challengers Bangalore
# 387  388    2013   Hyderabad  07/04/13  Royal Challengers Bangalore
# 115  116    2008      Mumbai  31/05/08              Kings XI Punjab
# 19    20    2017      Rajkot  18/04/17  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# 365              Kings XI Punjab              Deccan Chargers           bat
# 549  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 123  Royal Challengers Bangalore              Deccan Chargers           bat
# ...

# %%
IPL_Data.shape
# Out:
# (636, 18)

# %%
type(IPL_Data)
# Out:
# pandas.core.frame.DataFrame

# %%
Excel_Data = pd.read_excel(r'C:\Users\c\Desktop\DATA.xlsx',sheet_name = 'Sheet1')

# %%
Excel_Data
# Out:
#     Name      Add  Batch     Id
# 0  Robert     USA      1  12212
# 1     Bob  Canada      3    213
# 2   Reema   India      2   1233

# %% [markdown]
# ### Export data
# jab hamari excel or csv file kisi other folder me hai jahan hamara python install nahi hai tab us file ki ek extra copy banana di huilocation par

# %%
Excel_Data.to_excel(r'C:\Users\c\Desktop\DATA2.xlsx',index =False, header = True)

# %%
# jab hamari excel or csv file same folder me ho tab us file ki ek extra copy banana

# %%
Excel_Data.to_excel('DATA2.xlsx')
